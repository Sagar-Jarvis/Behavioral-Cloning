# %%
import numpy as np
import keras
import matplotlib.pyplot as plt
import csv
import cv2
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from keras.models import *
from keras.layers import *
from keras.optimizers import Adam
# %matplotlib inline

# %%
folder = './data_1/data/'
path = folder + 'driving_log.csv'

# %%
#resized image dimension in training
rows = 16
cols = 16

#batch size and epoch
batch_size=128
nb_epoch=9

# %%
# reading log files
log_tokens = []
with open(path,'rt') as f:
    reader = csv.reader(f)
    for line in reader:
        log_tokens.append(line)
log_labels = log_tokens.pop(0)

# %%
def image_preprocessing(img):
    """Training data in S channel of the HSV color space and resizing it to 16X16"""
    resized = cv2.resize((cv2.cvtColor(img, cv2.COLOR_RGB2HSV))[:,:,1],(cols, rows))
    return resized


def data_loading(imgs,steering,folder,correction=0.08):
    
    log_tokens = []
    with open(path,'rt') as f:
        reader = csv.reader(f)
        for line in reader:
            log_tokens.append(line)
    log_labels = log_tokens.pop(0)

    
    for i in range(len(log_tokens)):
        img_path = log_tokens[i][0]
        img_path = folder+'IMG'+(img_path.split('IMG')[1]).strip()
        img = plt.imread(img_path)
        imgs.append(image_preprocessing(img))
        steering.append(float(log_tokens[i][3]))

    for i in range(len(log_tokens)):
        img_path = log_tokens[i][1]
        img_path = folder+'IMG'+(img_path.split('IMG')[1]).strip()
        img = plt.imread(img_path)
        imgs.append(image_preprocessing(img))
        steering.append(float(log_tokens[i][3]) + correction)

    for i in range(len(log_tokens)):
        img_path = log_tokens[i][2]
        img_path = folder+'IMG'+(img_path.split('IMG')[1]).strip()
        img = plt.imread(img_path)
        imgs.append(image_preprocessing(img))
        steering.append(float(log_tokens[i][3]) - correction)


def main():
        
    images_train = np.array(data['Images']).astype('float32')
    steering_train = np.array(data['Steering']).astype('float32')
    
    #flip_train = np.fliplr(images_train)
    #images_train = np.append(images_train, flip_train, axis=0)

    images_train = np.append(images_train, images_train[:,:,::-1],axis=0)
    steering_train = np.append(steering_train, -steering_train,axis=0)
    
    X_train, y_train = shuffle(images_train, steering_train)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=0, test_size=0.1)

    X_train = X_train.reshape(X_train.shape[0], rows, cols, 1)
    X_val = X_val.reshape(X_val.shape[0], rows, cols, 1)

    model = Sequential()
    model.add(Lambda(lambda x: x/127.5 - 1.,input_shape=(rows,cols,1)))
    model.add(Conv2D(2, 3, 3, border_mode='valid', input_shape=(rows,cols,1), activation='elu'))
    model.add(MaxPooling2D((4,4),(4,4),'valid'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1))

    model.summary()

    model.compile(loss='mean_squared_error',optimizer='adam')
    history = model.fit(X_train, y_train,batch_size=batch_size, nb_epoch=nb_epoch,verbose=1, validation_data=(X_val, y_val))

    model.save("model21.h5")
    print("Model saved.")

# %%
img = plt.imread(folder + (log_tokens[25][0]).strip())
img_processed = (cv2.cvtColor(cv2.resize(img,(16,16)), cv2.COLOR_RGB2HSV))[:,:,1]

plt.subplot(2,1,1)
plt.imshow(img)
plt.subplot(2,1,2)
plt.imshow(img_processed,cmap='gray')

# %%
img = plt.imread(folder + (log_tokens[25][0]).strip())
img_processed = (cv2.cvtColor(cv2.resize(img,(16,16)), cv2.COLOR_RGB2HSV))[:,:,2]

plt.subplot(2,1,1)
plt.imshow(img)
plt.subplot(2,1,2)
plt.imshow(img_processed,cmap='gray')

# %%
img = plt.imread(folder + (log_tokens[25][0]).strip())
img_processed = (cv2.cvtColor(cv2.resize(img,(16,16)), cv2.COLOR_RGB2HSV))[:,:,0]

plt.subplot(2,1,1)
plt.imshow(img)
plt.subplot(2,1,2)
plt.imshow(img_processed,cmap='gray')

# %%
img = plt.imread(folder + (log_tokens[25][0]).strip())
img_processed = (cv2.cvtColor(cv2.resize(img,(16,16)), cv2.COLOR_RGB2GRAY))

plt.subplot(2,1,1)
plt.imshow(img)
plt.subplot(2,1,2)
plt.imshow(img_processed,cmap='gray')

# %%
data={}
data['Images'] = []
data['Steering'] = []

data_loading(data['Images'], data['Steering'],folder,0.3)

# %%
images_train = np.array(data['Images']).astype('float32')
steering_train = np.array(data['Steering']).astype('float32')

# %%
images_flipped_train = []
steering_flipped_train = []
images_flipped_train = np.append(images_train,images_train[:,:,::-1],axis=0)
steering_flipped_train = np.append(steering_train,-steering_train,axis=0)
i = 25
img_1 = images_train[i]
img_2 = images_flipped_train[i]
plt.subplot(2,1,1)
plt.imshow(img_1)
print(steering_train[i])
plt.subplot(2,1,2)
plt.imshow(img_2)
print(steering_flipped_train[i])
# Out:
# 0.0
# 0.0

# %%
images_train = np.append(images_train,images_train[:,:,::-1],axis=0)
steering_train = np.append(steering_train,-steering_train,axis=0)

# %%
X_train, y_train = shuffle(images_train, steering_train)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=0, test_size=0.1)

# %%
X_train = X_train.reshape(X_train.shape[0], rows, cols, 1)
X_val = X_val.reshape(X_val.shape[0], rows, cols, 1)

# %%
model = Sequential()
model.add(Lambda(lambda x: x/127.5 - 1.,input_shape=(rows,cols,1)))
model.add(Conv2D(2, 3, 3, border_mode='valid', input_shape=(rows,cols,1), activation='elu'))
model.add(MaxPooling2D((4,4),(4,4),'valid'))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1))

model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lambda_1 (Lambda)                (None, 16, 16, 1)     0           lambda_input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 14, 14, 2)     20          lambda_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 3, 3, 2)       0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 3, 3, 2)       0           maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 18)            0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1)             19          flatten_1[0][0]
# ====================================================================================================
# Total params: 39
# Trainable params: 39
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer='adam')
history = model.fit(X_train, y_train,batch_size=batch_size, nb_epoch=nb_epoch,verbose=1, validation_data=(X_val, y_val))
# Out:
# Train on 43394 samples, validate on 4822 samples
# Epoch 1/9
#  - ETA: 0s - loss: 0.1377
# Epoch 2/9
#  - ETA: 0s - loss: 0.0631
# Epoch 3/9
#  - ETA: 0s - loss: 0.0569
# Epoch 4/9
#  - ETA: 0s - loss: 0.0504
# Epoch 5/9
#  - ETA: 0s - loss: 0.0477

# %%
model.save("model21.h5")
print("Model saved.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93e40ea377c8> in <module>()
# ----> 1 model.save("model2.h5")
#       2 print("Model saved.")
#
# NameError: name 'model' is not defined

# %%
if __name__ == '__main__':
    
    data={}
    data['Images'] = []
    data['Steering'] = []

    data_loading(data['Images'], data['Steering'],folder,0.3)
    main()
